# %%
import numpy as np

# X = (hours studying, hours sleeping), y = score on test, xPredicted = 4 hours studying & 8 hours sleeping (input data for prediction)
X = np.array(([2, 9], [1, 5], [3, 6]), dtype=float)
y = np.array(([92], [86], [89]), dtype=float)
xPredicted = np.array(([4,8]), dtype=float)

# scale units
X = X/np.amax(X, axis=0) # maximum of X array
xPredicted = xPredicted/np.amax(xPredicted, axis=0) # maximum of xPredicted (our input data for the prediction)
y = y/100 # max test score is 100


class Neural_Network(object):
    def __init__(self):
        self.inputSize = 2
        self.outputSize = 1
        self.hiddenSize = 3
        self.W1 = np.random.randn(self.inputSize, self.hiddenSize) # (3x2) weight matrix from input to hidden layer
        self.W2 = np.random.randn(self.hiddenSize, self.outputSize) # (3x1) weight matrix from hidden to output layer

    def forward(self, X):
        self.z = np.dot(X, self.W1) # dot product of X (input) and first set of 3x2 weights
        self.z2 = self.sigmoid(self.z) # activation function
        self.z3 = np.dot(self.z2, self.W2) # dot product of hidden layer (z2) and second set of 3x1 weights
        o = self.sigmoid(self.z3) # final activation function
        return o

    def sigmoid(self, s):  
        return 1/(1+np.exp(-s))

    def sigmoidPrime(self, s):
        return s * (1 - s)
    
    def backward(self, X, y, o):
        self.o_error = y - o # error in output
        self.o_delta = self.o_error*self.sigmoidPrime(o) # applying derivative of sigmoid to error

        self.z2_error = self.o_delta.dot(self.W2.T) # z2 error: how much our hidden layer weights contributed to output error
        self.z2_delta = self.z2_error*self.sigmoidPrime(self.z2) # applying derivative of sigmoid to z2 error

        self.W1 += X.T.dot(self.z2_delta) # adjusting first set (input --> hidden) weights
        self.W2 += self.z2.T.dot(self.o_delta) # adjusting second set (hidden --> output) weights

    def train(self, X, y):
        o = self.forward(X)
        self.backward(X, y, o)
    
    def saveWeights(self):
        np.savetxt("w1.txt", self.W1, fmt="%s")
        np.savetxt("w2.txt", self.W2, fmt="%s")

    def predict(self):
        print("Predicted data based on trained weights: ")
        print("Input (scaled): \n" + str(xPredicted))
        print("Output: \n" + str(self.forward(xPredicted)))

NN = Neural_Network()
for i in range(1000): # trains the NN 1,000 times
    print("# " + str(i) + "\n")
    print("Input (scaled): \n" + str(X))
    print("Actual Output: \n" + str(y))
    print("Predicted Output: \n" + str(NN.forward(X)))
    print("Loss: \n" + str(np.mean(np.square(y - NN.forward(X))))) # mean sum squared loss
    print("\n")
    
    NN.train(X, y)
    NN.saveWeights()
    NN.predict()
# Out:
# # 0
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.44909988]
#  [0.44456098]
#  [0.43386175]]
# Loss:
# 0.20079953525004088
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.56980005]
# # 1
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.56949271]
#  [0.54997374]
#  [0.55345061]]
# Loss:
# 0.11074571284833307
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.65151386]
# # 2
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.65352181]
#  [0.6252824 ]
#  [0.63795767]]
# Loss:
# 0.06320943874531101
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.70457295]
# # 3
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.70783353]
#  [0.67527182]
#  [0.69307063]]
# Loss:
# 0.039306763577271885
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.74023746]
# # 4
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.7441818 ]
#  [0.70951217]
#  [0.73019087]]
# Loss:
# 0.026365862247540773
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.76554433]
# # 5
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.76987918]
#  [0.73418558]
#  [0.75655752]]
# Loss:
# 0.018724142262810287
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.78437695]
# # 6
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.78894385]
#  [0.75278039]
#  [0.77618937]]
# Loss:
# 0.013874873406973449
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.79893476]
# # 7
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.80364309]
#  [0.76730652]
#  [0.79136929]]
# Loss:
# 0.010619675401807893
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.81053113]
# # 8
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.81532645]
#  [0.77898119]
#  [0.80346286]]
# Loss:
# 0.008336425313872966
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.81999232]
# # 9
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.82484061]
#  [0.7885793 ]
#  [0.81333011]]
# Loss:
# 0.0066781660703728075
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.8278625]
# # 10
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.83274179]
#  [0.79661646]
#  [0.82153789]]
# Loss:
# 0.005439509868909294
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.83451424]
# # 11
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.83941004]
#  [0.80344891]
#  [0.82847451]]
# Loss:
# 0.004492717301487869
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.84021125]
# # 12
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.84511382]
#  [0.80933082]
#  [0.83441492]]
# Loss:
# 0.003755001985626696
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.84514547]
# # 13
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8500482 ]
#  [0.81444853]
#  [0.8395593 ]]
# Loss:
# 0.0031708183134509997
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.84946004]
# # 14
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.85435841]
#  [0.8189419 ]
#  [0.84405697]]
# Loss:
# 0.002701782367311848
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.85326395]
# # 15
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.85815489]
#  [0.82291809]
#  [0.84802166]]
# Loss:
# 0.002320688837952477
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.85664173]
# # 16
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.86152317]
#  [0.82646064]
#  [0.85154155]]
# Loss:
# 0.002007827138402487
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.85965997]
# # 17
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.86453053]
#  [0.82963572]
#  [0.85468615]]
# Loss:
# 0.001748639763219557
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.86237191]
# # 18
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.86723073]
#  [0.83249646]
#  [0.85751101]]
# Loss:
# 0.001532191648189874
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.86482061]
# # 19
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8696672 ]
#  [0.83508605]
#  [0.8600611 ]]
# Loss:
# 0.0013501446327797968
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.86704135]
# # 20
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.87187545]
#  [0.83743999]
#  [0.86237322]]
# Loss:
# 0.001196055087634901
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.86906328]
# # 21
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.87388485]
#  [0.83958775]
#  [0.8644778 ]]
# Loss:
# 0.0010648833292871086
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.87091073]
# # 22
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.87571985]
#  [0.841554  ]
#  [0.86640026]]
# Loss:
# 0.0009526448545121476
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.87260418]
# # 23
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.87740103]
#  [0.84335959]
#  [0.86816197]]
# Loss:
# 0.000856158406357552
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.874161]
# # 24
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.87894583]
#  [0.84502226]
#  [0.86978104]]
# Loss:
# 0.0007728613302933519
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.87559602]
# # 25
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88036912]
#  [0.84655719]
#  [0.87127298]]
# Loss:
# 0.0007006724475589195
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.87692199]
# # 26
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88168368]
#  [0.84797748]
#  [0.87265107]]
# Loss:
# 0.0006378889783906612
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.87814991]
# # 27
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88290055]
#  [0.84929447]
#  [0.87392683]]
# Loss:
# 0.0005831081949316836
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.87928938]
# # 28
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88402932]
#  [0.85051807]
#  [0.87511025]]
# Loss:
# 0.0005351672583462962
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.88034876]
# # 29
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88507836]
#  [0.85165693]
#  [0.87621007]]
# Loss:
# 0.0004930965807176641
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.8813354]
# # 30
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88605503]
#  [0.85271868]
#  [0.87723396]]
# Loss:
# 0.00045608335315202865
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.88225578]
# # 31
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8869658 ]
#  [0.85371008]
#  [0.87818869]]
# Loss:
# 0.00042344279093429923
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.88311564]
# # 32
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8878164 ]
#  [0.85463709]
#  [0.87908024]]
# Loss:
# 0.00039459529038376513
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.88392008]
# # 33
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88861192]
#  [0.85550504]
#  [0.87991394]]
# Loss:
# 0.0003690481531814975
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.88467364]
# # 34
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88935691]
#  [0.85631871]
#  [0.88069454]]
# Loss:
# 0.0003463808678389019
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.8853804]
# # 35
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89005541]
#  [0.85708236]
#  [0.88142628]]
# Loss:
# 0.0003262331822296734
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.88604402]
# # 36
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89071109]
#  [0.85779983]
#  [0.88211299]]
# Loss:
# 0.00030829538149944926
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.88666778]
# # 37
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89132721]
#  [0.8584746 ]
#  [0.8827581 ]]
# Loss:
# 0.0002923003200961199
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.88725466]
# # 38
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89190674]
#  [0.85910979]
#  [0.88336471]]
# Loss:
# 0.0002780168576903547
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.88780736]
# # 39
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89245237]
#  [0.85970826]
#  [0.88393564]]
# Loss:
# 0.00026524442528663776
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.88832833]
# # 40
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89296653]
#  [0.86027259]
#  [0.88447344]]
# Loss:
# 0.00025380850623683463
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.88881978]
# # 41
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89345144]
#  [0.86080514]
#  [0.88498043]]
# Loss:
# 0.00024355686176868877
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.88928374]
# # 42
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8939091 ]
#  [0.86130807]
#  [0.88545873]]
# Loss:
# 0.00023435636538898533
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.88972208]
# # 43
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89434138]
#  [0.86178335]
#  [0.88591029]]
# Loss:
# 0.0002260903375836216
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.8901365]
# # 44
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89474995]
#  [0.8622328 ]
#  [0.88633686]]
# Loss:
# 0.0002186562934417706
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89052855]
# # 45
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89513638]
#  [0.86265806]
#  [0.88674009]]
# Loss:
# 0.00021196403254300145
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89089966]
# # 46
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89550207]
#  [0.86306068]
#  [0.88712147]]
# Loss:
# 0.00020593401368875015
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89125117]
# # 47
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89584836]
#  [0.86344207]
#  [0.88748238]]
# Loss:
# 0.00020049596760833704
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89158429]
# # 48
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89617645]
#  [0.86380353]
#  [0.8878241 ]]
# Loss:
# 0.00019558770921455348
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89190015]
# # 49
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89648745]
#  [0.86414626]
#  [0.88814779]]
# Loss:
# 0.00019115411777662484
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89219979]
# # 50
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8967824 ]
#  [0.8644714 ]
#  [0.88845455]]
# Loss:
# 0.00018714625886733006
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89248418]
# # 51
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89706226]
#  [0.86477997]
#  [0.88874539]]
# Loss:
# 0.00018352062639559054
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89275422]
# # 52
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89732793]
#  [0.86507294]
#  [0.88902124]]
# Loss:
# 0.0001802384866662497
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89301073]
# # 53
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89758022]
#  [0.86535121]
#  [0.88928298]]
# Loss:
# 0.00017726530937908292
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.8932545]
# # 54
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89781992]
#  [0.86561562]
#  [0.88953142]]
# Loss:
# 0.00017457027291903102
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89348625]
# # 55
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89804772]
#  [0.86586693]
#  [0.8897673 ]]
# Loss:
# 0.00017212583330086407
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89370665]
# # 56
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89826431]
#  [0.86610588]
#  [0.88999133]]
# Loss:
# 0.00016990734779558637
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89391633]
# # 57
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89847031]
#  [0.86633316]
#  [0.89020418]]
# Loss:
# 0.0001678927456472926
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89411589]
# # 58
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89866629]
#  [0.86654939]
#  [0.89040646]]
# Loss:
# 0.0001660622394395827
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89430587]
# # 59
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89885282]
#  [0.86675517]
#  [0.89059873]]
# Loss:
# 0.0001643980716319063
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89448679]
# # 60
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89903038]
#  [0.86695106]
#  [0.89078155]]
# Loss:
# 0.00016288429159169767
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89465914]
# # 61
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89919948]
#  [0.86713759]
#  [0.8909554 ]]
# Loss:
# 0.00016150655912514753
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89482336]
# # 62
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89936055]
#  [0.86731524]
#  [0.89112078]]
# Loss:
# 0.00016025197108014417
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89497988]
# # 63
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89951401]
#  [0.86748448]
#  [0.89127812]]
# Loss:
# 0.00015910890807703678
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89512911]
# # 64
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89966027]
#  [0.86764574]
#  [0.89142785]]
# Loss:
# 0.00015806689883171972
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89527142]
# # 65
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8997997 ]
#  [0.86779944]
#  [0.89157034]]
# Loss:
# 0.00015711649988246076
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89540716]
# # 66
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89993264]
#  [0.86794595]
#  [0.89170599]]
# Loss:
# 0.00015624918882777862
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89553668]
# # 67
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90005943]
#  [0.86808564]
#  [0.89183512]]
# Loss:
# 0.00015545726943482974
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89566028]
# # 68
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90018037]
#  [0.86821886]
#  [0.89195808]]
# Loss:
# 0.0001547337871938752
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89577826]
# # 69
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90029577]
#  [0.86834592]
#  [0.89207518]]
# Loss:
# 0.00015407245407944898
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.8958909]
# # 70
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9004059 ]
#  [0.86846714]
#  [0.89218669]]
# Loss:
# 0.00015346758143796078
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89599847]
# # 71
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90051102]
#  [0.86858279]
#  [0.89229291]]
# Loss:
# 0.00015291402005860382
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89610121]
# # 72
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90061138]
#  [0.86869316]
#  [0.8923941 ]]
# Loss:
# 0.00015240710660253034
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89619937]
# # 73
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90070721]
#  [0.8687985 ]
#  [0.89249049]]
# Loss:
# 0.00015194261566752596
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89629316]
# # 74
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90079873]
#  [0.86889905]
#  [0.89258233]]
# Loss:
# 0.00015151671685404347
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89638281]
# # 75
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90088616]
#  [0.86899505]
#  [0.89266983]]
# Loss:
# 0.00015112593627511145
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.8964685]
# # 76
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90096968]
#  [0.86908671]
#  [0.8927532 ]]
# Loss:
# 0.0001507671220196257
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89655043]
# # 77
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9010495 ]
#  [0.86917425]
#  [0.89283264]]
# Loss:
# 0.00015043741313655186
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89662877]
# # 78
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90112577]
#  [0.86925785]
#  [0.89290835]]
# Loss:
# 0.00015013421175838658
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89670371]
# # 79
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90119869]
#  [0.8693377 ]
#  [0.89298049]]
# Loss:
# 0.00014985515802651717
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.8967754]
# # 80
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90126839]
#  [0.86941399]
#  [0.89304924]]
# Loss:
# 0.00014959810751998128
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89684398]
# # 81
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90133504]
#  [0.86948688]
#  [0.89311475]]
# Loss:
# 0.0001493611109229985
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89690962]
# # 82
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90139878]
#  [0.86955652]
#  [0.89317718]]
# Loss:
# 0.00014914239569664616
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89697245]
# # 83
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90145974]
#  [0.86962308]
#  [0.89323668]]
# Loss:
# 0.00014894034954617618
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89703259]
# # 84
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90151805]
#  [0.86968669]
#  [0.89329337]]
# Loss:
# 0.00014875350549856573
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89709018]
# # 85
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90157385]
#  [0.86974748]
#  [0.8933474 ]]
# Loss:
# 0.00014858052842533435
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89714533]
# # 86
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90162724]
#  [0.8698056 ]
#  [0.89339888]]
# Loss:
# 0.00014842020286350046
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89719815]
# # 87
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90167833]
#  [0.86986116]
#  [0.89344793]]
# Loss:
# 0.0001482714220034954
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89724876]
# # 88
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90172724]
#  [0.86991428]
#  [0.89349466]]
# Loss:
# 0.00014813317772690277
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89729725]
# # 89
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90177406]
#  [0.86996508]
#  [0.89353918]]
# Loss:
# 0.00014800455158930166
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89734372]
# # 90
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90181888]
#  [0.87001365]
#  [0.8935816 ]]
# Loss:
# 0.00014788470665448483
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89738826]
# # 91
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90186181]
#  [0.87006011]
#  [0.893622  ]]
# Loss:
# 0.00014777288009625817
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89743096]
# # 92
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90190292]
#  [0.87010454]
#  [0.89366048]]
# Loss:
# 0.00014766837649257
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89747191]
# # 93
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9019423 ]
#  [0.87014704]
#  [0.89369713]]
# Loss:
# 0.00014757056174456
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89751118]
# # 94
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90198002]
#  [0.87018769]
#  [0.89373203]]
# Loss:
# 0.0001474788575600076
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89754885]
# # 95
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90201617]
#  [0.87022658]
#  [0.89376525]]
# Loss:
# 0.0001473927364467968
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89758499]
# # 96
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90205081]
#  [0.87026379]
#  [0.89379689]]
# Loss:
# 0.00014731171716750823
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89761968]
# # 97
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90208401]
#  [0.8702994 ]
#  [0.89382699]]
# Loss:
# 0.00014723536061115358
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89765296]
# # 98
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90211584]
#  [0.87033347]
#  [0.89385565]]
# Loss:
# 0.00014716326604245086
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89768492]
# # 99
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90214636]
#  [0.87036608]
#  [0.89388291]]
# Loss:
# 0.0001470950676929953
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89771561]
# # 100
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90217562]
#  [0.87039729]
#  [0.89390885]]
# Loss:
# 0.0001470304316621128
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89774508]
# # 101
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90220368]
#  [0.87042716]
#  [0.89393352]]
# Loss:
# 0.00014696905309845822
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89777339]
# # 102
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9022306 ]
#  [0.87045575]
#  [0.89395698]]
# Loss:
# 0.00014691065363608874
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89780059]
# # 103
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90225643]
#  [0.87048312]
#  [0.89397928]]
# Loss:
# 0.00014685497906146867
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89782674]
# # 104
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90228121]
#  [0.87050933]
#  [0.89400048]]
# Loss:
# 0.00014680179718993668
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89785187]
# # 105
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90230499]
#  [0.87053442]
#  [0.89402062]]
# Loss:
# 0.0001467508959324014
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89787603]
# # 106
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90232782]
#  [0.87055844]
#  [0.89403975]]
# Loss:
# 0.00014670208153473913
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89789927]
# # 107
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90234974]
#  [0.87058145]
#  [0.89405791]]
# Loss:
# 0.00014665517697411663
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89792162]
# # 108
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90237078]
#  [0.87060349]
#  [0.89407516]]
# Loss:
# 0.0001466100204978842
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89794313]
# # 109
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.902391  ]
#  [0.87062459]
#  [0.89409152]]
# Loss:
# 0.00014656646429210893
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89796384]
# # 110
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90241042]
#  [0.87064481]
#  [0.89410704]]
# Loss:
# 0.0001465243732679664
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89798377]
# # 111
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90242908]
#  [0.87066417]
#  [0.89412176]]
# Loss:
# 0.00014648362395534433
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89800296]
# # 112
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90244701]
#  [0.87068273]
#  [0.89413571]]
# Loss:
# 0.00014644410349400747
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89802145]
# # 113
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90246424]
#  [0.8707005 ]
#  [0.89414892]]
# Loss:
# 0.00014640570871351103
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89803926]
# # 114
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90248081]
#  [0.87071754]
#  [0.89416143]]
# Loss:
# 0.00014636834529395718
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89805643]
# # 115
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90249675]
#  [0.87073386]
#  [0.89417327]]
# Loss:
# 0.0001463319270003374
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89807298]
# # 116
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90251208]
#  [0.87074951]
#  [0.89418446]]
# Loss:
# 0.000146296374983891
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89808894]
# # 117
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90252682]
#  [0.8707645 ]
#  [0.89419504]]
# Loss:
# 0.00014626161714452728
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89810434]
# # 118
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90254101]
#  [0.87077888]
#  [0.89420504]]
# Loss:
# 0.00014622758754888486
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.8981192]
# # 119
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90255467]
#  [0.87079266]
#  [0.89421447]]
# Loss:
# 0.00014619422589909112
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89813355]
# # 120
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90256783]
#  [0.87080588]
#  [0.89422337]]
# Loss:
# 0.0001461614770477462
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.8981474]
# # 121
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90258049]
#  [0.87081855]
#  [0.89423175]]
# Loss:
# 0.00014612929055506817
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89816078]
# # 122
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9025927 ]
#  [0.8708307 ]
#  [0.89423964]]
# Loss:
# 0.00014609762028444006
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89817371]
# # 123
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90260445]
#  [0.87084236]
#  [0.89424707]]
# Loss:
# 0.0001460664240330233
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.8981862]
# # 124
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90261579]
#  [0.87085354]
#  [0.89425404]]
# Loss:
# 0.0001460356631943483
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89819829]
# # 125
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90262671]
#  [0.87086426]
#  [0.89426059]]
# Loss:
# 0.000146005302450089
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89820998]
# # 126
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90263725]
#  [0.87087456]
#  [0.89426673]]
# Loss:
# 0.00014597530948843714
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89822129]
# # 127
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90264742]
#  [0.87088443]
#  [0.89427247]]
# Loss:
# 0.0001459456547467854
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89823224]
# # 128
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90265723]
#  [0.87089391]
#  [0.89427784]]
# Loss:
# 0.0001459163111765995
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89824285]
# # 129
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9026667 ]
#  [0.87090301]
#  [0.89428285]]
# Loss:
# 0.0001458872540285257
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89825312]
# # 130
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90267584]
#  [0.87091175]
#  [0.89428752]]
# Loss:
# 0.00014585846065598456
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89826308]
# # 131
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90268468]
#  [0.87092014]
#  [0.89429186]]
# Loss:
# 0.00014582991033565139
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89827274]
# # 132
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90269322]
#  [0.87092819]
#  [0.89429588]]
# Loss:
# 0.00014580158410336416
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.8982821]
# # 133
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90270147]
#  [0.87093593]
#  [0.89429961]]
# Loss:
# 0.0001457734646040785
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89829119]
# # 134
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90270945]
#  [0.87094336]
#  [0.89430305]]
# Loss:
# 0.00014574553595473005
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89830002]
# # 135
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90271716]
#  [0.8709505 ]
#  [0.89430621]]
# Loss:
# 0.00014571778361882577
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89830859]
# # 136
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90272463]
#  [0.87095736]
#  [0.89430911]]
# Loss:
# 0.00014569019429176242
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89831692]
# # 137
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90273186]
#  [0.87096396]
#  [0.89431176]]
# Loss:
# 0.00014566275579598297
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89832502]
# # 138
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90273886]
#  [0.8709703 ]
#  [0.89431417]]
# Loss:
# 0.00014563545698507952
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89833289]
# # 139
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90274565]
#  [0.8709764 ]
#  [0.89431636]]
# Loss:
# 0.0001456082876560948
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89834056]
# # 140
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90275222]
#  [0.87098226]
#  [0.89431832]]
# Loss:
# 0.00014558123846931798
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89834802]
# # 141
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9027586 ]
#  [0.8709879 ]
#  [0.89432007]]
# Loss:
# 0.00014555430087491393
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89835528]
# # 142
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90276478]
#  [0.87099333]
#  [0.89432162]]
# Loss:
# 0.00014552746704582886
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89836236]
# # 143
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90277078]
#  [0.87099855]
#  [0.89432298]]
# Loss:
# 0.00014550072981640621
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89836926]
# # 144
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90277661]
#  [0.87100357]
#  [0.89432416]]
# Loss:
# 0.00014547408262623285
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89837599]
# # 145
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90278226]
#  [0.87100841]
#  [0.89432516]]
# Loss:
# 0.000145447519468772
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89838256]
# # 146
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90278776]
#  [0.87101307]
#  [0.89432599]]
# Loss:
# 0.00014542103484436555
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.89838897]
# # 147
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9027931 ]
#  [0.87101756]
#  [0.89432666]]
# Loss:
# 0.00014539462371723698
#
#
# Predicted data based on trained weights:
# Input (scaled):
# ...
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.90042888]
# # 951
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90420482]
#  [0.87149364]
#  [0.89255147]]
# Loss:
# 0.00012936712597225248
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.90043085]
# # 952
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90420622]
#  [0.87149393]
#  [0.89254969]]
# Loss:
# 0.00012935160419979186
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.90043283]
# # 953
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90420762]
#  [0.87149423]
#  [0.89254792]]
# Loss:
# 0.000129336090406952
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.9004348]
# # 954
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90420902]
#  [0.87149452]
#  [0.89254614]]
# Loss:
# 0.000129320584585038
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.90043677]
# # 955
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90421042]
#  [0.87149481]
#  [0.89254437]]
# Loss:
# 0.00012930508672537265
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.90043875]
# # 956
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90421182]
#  [0.8714951 ]
#  [0.8925426 ]]
# Loss:
# 0.00012928959681928948
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.90044072]
# # 957
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90421322]
#  [0.87149539]
#  [0.89254083]]
# Loss:
# 0.00012927411485812274
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.90044269]
# # 958
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90421461]
#  [0.87149568]
#  [0.89253906]]
# Loss:
# 0.00012925864083322697
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.90044466]
# # 959
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90421601]
#  [0.87149597]
#  [0.8925373 ]]
# Loss:
# 0.00012924317473595725
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.90044662]
# # 960
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9042174 ]
#  [0.87149626]
#  [0.89253553]]
# Loss:
# 0.00012922771655768478
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.90044859]
# # 961
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9042188 ]
#  [0.87149655]
#  [0.89253376]]
# Loss:
# 0.00012921226628978828
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.90045056]
# # 962
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90422019]
#  [0.87149683]
#  [0.892532  ]]
# Loss:
# 0.00012919682392365545
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.90045252]
# # 963
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90422159]
#  [0.87149712]
#  [0.89253024]]
# Loss:
# 0.0001291813894506855
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.90045449]
# # 964
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90422298]
#  [0.87149741]
#  [0.89252847]]
# Loss:
# 0.00012916596286228514
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.90045645]
# # 965
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90422437]
#  [0.8714977 ]
#  [0.89252671]]
# Loss:
# 0.00012915054414987186
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.90045841]
# # 966
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90422577]
#  [0.87149798]
#  [0.89252495]]
# Loss:
# 0.00012913513330487322
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.90046037]
# # 967
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90422716]
#  [0.87149827]
#  [0.8925232 ]]
# Loss:
# 0.00012911973031872406
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.90046233]
# # 968
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90422855]
#  [0.87149855]
#  [0.89252144]]
# Loss:
# 0.00012910433518287194
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.90046429]
# # 969
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90422994]
#  [0.87149884]
#  [0.89251968]]
# Loss:
# 0.00012908894788877278
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.90046625]
# # 970
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90423133]
#  [0.87149912]
#  [0.89251793]]
# Loss:
# 0.00012907356842789262
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.90046821]
# # 971
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90423272]
#  [0.87149941]
#  [0.89251617]]
# Loss:
# 0.00012905819679170604
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.90047016]
# # 972
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90423411]
#  [0.87149969]
#  [0.89251442]]
# Loss:
# 0.00012904283297169778
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.90047212]
# # 973
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9042355 ]
#  [0.87149997]
#  [0.89251267]]
# Loss:
# 0.0001290274769593624
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.90047407]
# # 974
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90423689]
#  [0.87150026]
#  [0.89251092]]
# Loss:
# 0.00012901212874620162
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.90047603]
# # 975
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90423827]
#  [0.87150054]
#  [0.89250917]]
# Loss:
# 0.00012899678832373153
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.90047798]
# # 976
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90423966]
#  [0.87150082]
#  [0.89250742]]
# Loss:
# 0.0001289814556834731
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.90047993]
# # 977
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90424105]
#  [0.8715011 ]
#  [0.89250567]]
# Loss:
# 0.00012896613081696205
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.90048188]
# # 978
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90424243]
#  [0.87150138]
#  [0.89250392]]
# Loss:
# 0.00012895081371573543
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.90048383]
# # 979
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90424382]
#  [0.87150167]
#  [0.89250218]]
# Loss:
# 0.000128935504371348
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.90048578]
# # 980
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9042452 ]
#  [0.87150195]
#  [0.89250043]]
# Loss:
# 0.00012892020277536234
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.90048773]
# # 981
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90424659]
#  [0.87150223]
#  [0.89249869]]
# Loss:
# 0.00012890490891934143
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.90048967]
# # 982
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90424797]
#  [0.87150251]
#  [0.89249695]]
# Loss:
# 0.00012888962279487378
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.90049162]
# # 983
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90424935]
#  [0.87150278]
#  [0.89249521]]
# Loss:
# 0.00012887434439354405
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.90049356]
# # 984
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90425073]
#  [0.87150306]
#  [0.89249347]]
# Loss:
# 0.00012885907370695397
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.90049551]
# # 985
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90425212]
#  [0.87150334]
#  [0.89249173]]
# Loss:
# 0.0001288438107267084
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.90049745]
# # 986
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9042535 ]
#  [0.87150362]
#  [0.89248999]]
# Loss:
# 0.00012882855544442878
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.90049939]
# # 987
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90425488]
#  [0.8715039 ]
#  [0.89248826]]
# Loss:
# 0.00012881330785173965
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.90050133]
# # 988
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90425626]
#  [0.87150417]
#  [0.89248652]]
# Loss:
# 0.0001287980679402778
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.90050327]
# # 989
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90425764]
#  [0.87150445]
#  [0.89248479]]
# Loss:
# 0.0001287828357016916
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.90050521]
# # 990
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90425902]
#  [0.87150473]
#  [0.89248305]]
# Loss:
# 0.00012876761112763448
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.90050715]
# # 991
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90426039]
#  [0.871505  ]
#  [0.89248132]]
# Loss:
# 0.0001287523942097708
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.90050908]
# # 992
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90426177]
#  [0.87150528]
#  [0.89247959]]
# Loss:
# 0.00012873718493977462
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.90051102]
# # 993
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90426315]
#  [0.87150555]
#  [0.89247786]]
# Loss:
# 0.0001287219833093344
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.90051295]
# # 994
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90426453]
#  [0.87150583]
#  [0.89247613]]
# Loss:
# 0.00012870678931013532
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.90051489]
# # 995
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9042659]
#  [0.8715061]
#  [0.8924744]]
# Loss:
# 0.00012869160293388699
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.90051682]
# # 996
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90426728]
#  [0.87150637]
#  [0.89247268]]
# Loss:
# 0.00012867642417229482
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.90051875]
# # 997
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90426865]
#  [0.87150665]
#  [0.89247095]]
# Loss:
# 0.0001286612530170834
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.90052068]
# # 998
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90427003]
#  [0.87150692]
#  [0.89246923]]
# Loss:
# 0.0001286460894599845
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.90052261]
# # 999
#
# Input (scaled):
# [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9042714 ]
#  [0.87150719]
#  [0.8924675 ]]
# Loss:
# 0.0001286309334927327
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [0.5 1. ]
# Output:
# [0.90052454]
